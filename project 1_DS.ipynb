# %% [markdown]
# # Business Understanding

# %% [markdown]
# # step 1  Pick a dataset and Import packages

# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# In this notebook Iam using predict price value by Random Forest Regressor and Linear Regressor , visual tool of dataset and trying to answer important questions .
# I am selecting Boston AirBnB listings as my dataset for the study. It is available on Kaggle. Listings dataset has various features/columns such as neighborhood, property_type, bedrooms, bathrooms, beds, price, reviews, ratings, etc.
#
#
# Airbnb is an American vacation rental online marketplace company based in San Francisco, California. Airbnb maintains and hosts a marketplace, accessible to consumers on its website or app. Users can arrange lodging, primarily homestays, and tourism experiences or list their spare rooms, properties, or part of it for rental. On the other hand, users who are traveling are looking for stays search properties and rooms by neighborhood or location. Airbnb recommends the best price in the neighborhood and users book the best deal.

# %% [markdown]
# #  Data Understanding

# %% [markdown]
# ### read Boston Airbnb datasets

# %%
_listings_raw = pd.read_csv('listings.csv', index_col = "id")

_listings = _listings_raw.copy()

# %% [markdown]
# # step 2 : three questions
# ### we answering following questions:

# %%
#What Features are affecting the price most? name the features that affect the price most.
#Can we predict the price of a listing in Boston AirBnB?
#What is the highest proportion in each cancellation_policy category ?
#What is the highest proportion in each review_scores_rating category ?

# %% [markdown]
# # step 3:  Prepare data

# %% [markdown]
# ### Exploring dataset

# %%
# check of dataset shape
print(_listings.shape)
# Out:
# (3585, 94)

# %% [markdown]
# The Boston Airbnb listings dataset has 3585 rows and 94 columns.

# %%
#check dataset info
print(_listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3585 entries, 12147973 to 14504422
# Data columns (total 94 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_url                       3585 non-null   object
#  1   scrape_id                         3585 non-null   float64
#  2   last_scraped                      3585 non-null   object
#  3   name                              3585 non-null   object
#  4   summary                           3442 non-null   object
#  5   space                             2528 non-null   object
#  6   description                       3585 non-null   object
#  7   experiences_offered               3585 non-null   object
#  8   neighborhood_overview             2170 non-null   object
#  9   notes                             1610 non-null   object
#  10  transit                           2295 non-null   object
#  11  access                            2096 non-null   object
#  12  interaction                       2031 non-null   object
#  13  house_rules                       2393 non-null   object
#  14  thumbnail_url                     2986 non-null   object
#  15  medium_url                        2986 non-null   object
#  16  picture_url                       3585 non-null   object
#  17  xl_picture_url                    2986 non-null   object
#  18  host_id                           3585 non-null   int64
#  19  host_url                          3585 non-null   object
#  20  host_name                         3585 non-null   object
#  21  host_since                        3585 non-null   object
#  22  host_location                     3574 non-null   object
#  23  host_about                        2276 non-null   object
#  24  host_response_time                3114 non-null   object
#  25  host_response_rate                3114 non-null   object
#  26  host_acceptance_rate              3114 non-null   object
#  27  host_is_superhost                 3585 non-null   object
#  28  host_thumbnail_url                3585 non-null   object
#  29  host_picture_url                  3585 non-null   object
#  30  host_neighbourhood                3246 non-null   object
#  31  host_listings_count               3585 non-null   int64
#  32  host_total_listings_count         3585 non-null   int64
#  33  host_verifications                3585 non-null   object
#  34  host_has_profile_pic              3585 non-null   object
#  35  host_identity_verified            3585 non-null   object
#  36  street                            3585 non-null   object
#  37  neighbourhood                     3042 non-null   object
#  38  neighbourhood_cleansed            3585 non-null   object
#  39  neighbourhood_group_cleansed      0 non-null      float64
#  40  city                              3583 non-null   object
#  41  state                             3585 non-null   object
#  42  zipcode                           3547 non-null   object
#  43  market                            3571 non-null   object
#  44  smart_location                    3585 non-null   object
#  45  country_code                      3585 non-null   object
#  46  country                           3585 non-null   object
#  47  latitude                          3585 non-null   float64
#  48  longitude                         3585 non-null   float64
#  49  is_location_exact                 3585 non-null   object
#  50  property_type                     3582 non-null   object
#  51  room_type                         3585 non-null   object
#  52  accommodates                      3585 non-null   int64
#  53  bathrooms                         3571 non-null   float64
#  54  bedrooms                          3575 non-null   float64
#  55  beds                              3576 non-null   float64
#  56  bed_type                          3585 non-null   object
#  57  amenities                         3585 non-null   object
#  58  square_feet                       56 non-null     float64
#  59  price                             3585 non-null   object
#  60  weekly_price                      892 non-null    object
#  61  monthly_price                     888 non-null    object
#  62  security_deposit                  1342 non-null   object
#  63  cleaning_fee                      2478 non-null   object
#  64  guests_included                   3585 non-null   int64
#  65  extra_people                      3585 non-null   object
#  66  minimum_nights                    3585 non-null   int64
#  67  maximum_nights                    3585 non-null   int64
#  68  calendar_updated                  3585 non-null   object
#  69  has_availability                  0 non-null      float64
#  70  availability_30                   3585 non-null   int64
#  71  availability_60                   3585 non-null   int64
#  72  availability_90                   3585 non-null   int64
#  73  availability_365                  3585 non-null   int64
#  74  calendar_last_scraped             3585 non-null   object
#  75  number_of_reviews                 3585 non-null   int64
#  76  first_review                      2829 non-null   object
#  77  last_review                       2829 non-null   object
#  78  review_scores_rating              2772 non-null   float64
#  79  review_scores_accuracy            2762 non-null   float64
#  80  review_scores_cleanliness         2767 non-null   float64
#  81  review_scores_checkin             2765 non-null   float64
#  82  review_scores_communication       2767 non-null   float64
#  83  review_scores_location            2763 non-null   float64
#  84  review_scores_value               2764 non-null   float64
#  85  requires_license                  3585 non-null   object
#  86  license                           0 non-null      float64
#  87  jurisdiction_names                0 non-null      float64
#  88  instant_bookable                  3585 non-null   object
#  89  cancellation_policy               3585 non-null   object
#  90  require_guest_profile_picture     3585 non-null   object
#  91  require_guest_phone_verification  3585 non-null   object
#  92  calculated_host_listings_count    3585 non-null   int64
#  93  reviews_per_month                 2829 non-null   float64
# dtypes: float64(19), int64(13), object(62)
# memory usage: 2.6+ MB
# None

# %% [markdown]
# Some columns have very few non-null values,
# There are columns are not useful ,
# There are columns are of type object.

# %%
# print dataset 
_listings
# Out:
#                                     listing_url     scrape_id last_scraped  \
# id
# 12147973  https://www.airbnb.com/rooms/12147973  2.016090e+13     9/7/2016
# 3075044    https://www.airbnb.com/rooms/3075044  2.016090e+13     9/7/2016
# 6976          https://www.airbnb.com/rooms/6976  2.016090e+13     9/7/2016
# 1436513    https://www.airbnb.com/rooms/1436513  2.016090e+13     9/7/2016
# 7651065    https://www.airbnb.com/rooms/7651065  2.016090e+13     9/7/2016
# ...                                         ...           ...          ...
# 8373729    https://www.airbnb.com/rooms/8373729  2.016090e+13     9/7/2016
# 14844274  https://www.airbnb.com/rooms/14844274  2.016090e+13     9/7/2016
# 14585486  https://www.airbnb.com/rooms/14585486  2.016090e+13     9/7/2016
# 14603878  https://www.airbnb.com/rooms/14603878  2.016090e+13     9/7/2016
# 14504422  https://www.airbnb.com/rooms/14504422  2.016090e+13     9/7/2016
#
#                                                    name  \
# id
# 12147973                     Sunny Bungalow in the City
# 3075044               Charming room in pet friendly apt
# 6976                   Mexican Folk Art Haven in Boston
# 1436513   Spacious Sunny Bedroom Suite in Historic Home
# 7651065                             Come Home to Boston
# ...                                                 ...
# 8373729                            Big cozy room near T
# 14844274            BU Apartment DexterPark Bright room
# 14585486                       Gorgeous funky apartment
# 14603878          Great Location; Train and Restaurants
# 14504422             (K1) Private Room near Harvard/MIT
#
#                                                     summary  \
# id
# 12147973  Cozy, sunny, family home.  Master bedroom high...
# 3075044   Charming and quiet room in a second floor 1910...
# 6976      Come stay with a friendly, middle-aged guy in ...
# 1436513   Come experience the comforts of home away from...
# 7651065   My comfy, clean and relaxing home is one block...
# ...                                                     ...
# 8373729   5 min walking to Orange Line subway with 2 sto...
# 14844274  Most popular apartment in BU, best located in ...
# 14585486  Funky little apartment close to public transpo...
# 14603878  My place is close to Taco Loco Mexican Grill, ...
# 14504422  My place is close to My home is a warm and fri...
#
#                                                       space  \
# id
# 12147973  The house has an open and cozy feel at the sam...
# 3075044   Small but cozy and quite room with a full size...
# 6976      Come stay with a friendly, middle-aged guy in ...
# 1436513   Most places you find in Boston are small howev...
# 7651065   Clean, attractive, private room, one block fro...
# ...                                                     ...
# 8373729                                                 NaN
# 14844274                                Best location in BU
# 14585486  Modern and relaxed space with many facilities ...
# 14603878                                                NaN
# 14504422  To ensure a smooth check in: 1. You MUST have ...
#
#                                                 description  \
# id
# 12147973  Cozy, sunny, family home.  Master bedroom high...
# 3075044   Charming and quiet room in a second floor 1910...
# 6976      Come stay with a friendly, middle-aged guy in ...
# 1436513   Come experience the comforts of home away from...
# 7651065   My comfy, clean and relaxing home is one block...
# ...                                                     ...
# 8373729   5 min walking to Orange Line subway with 2 sto...
# 14844274  Most popular apartment in BU, best located in ...
# 14585486  Funky little apartment close to public transpo...
# 14603878  My place is close to Taco Loco Mexican Grill, ...
# 14504422  My place is close to My home is a warm and fri...
#
#          experiences_offered  \
# id
# 12147973                none
# 3075044                 none
# 6976                    none
# 1436513                 none
# 7651065                 none
# ...                      ...
# 8373729                 none
# 14844274                none
# 14585486                none
# 14603878                none
# 14504422                none
#
#                                       neighborhood_overview  \
# id
# 12147973  Roslindale is quiet, convenient and friendly. ...
# 3075044   The room is in Roslindale, a diverse and prima...
# 6976      The LOCATION: Roslindale is a safe and diverse...
# 1436513   Roslindale is a lovely little neighborhood loc...
# 7651065   I love the proximity to downtown, the neighbor...
# ...                                                     ...
# 8373729                                                 NaN
# 14844274                                                NaN
# 14585486  Cambridge is a short walk into Boston, and set...
# 14603878                                                NaN
# 14504422                                                NaN
#
#                                                       notes  ...  \
# id                                                           ...
# 12147973                                                NaN  ...
# 3075044   If you don't have a US cell phone, you can tex...  ...
# 6976      I am in a scenic part of Boston with a couple ...  ...
# 1436513   Please be mindful of the property as it is old...  ...
# 7651065   I have one roommate who lives on the lower lev...  ...
# ...                                                     ...  ...
# 8373729                                                 NaN  ...
# 14844274                                                NaN  ...
# 14585486  Depending on when you arrive, I can be here to...  ...
# 14603878                                                NaN  ...
# 14504422                                                NaN  ...
#
#          review_scores_value requires_license license jurisdiction_names  \
# id
# 12147973                 NaN                f     NaN                NaN
# 3075044                  9.0                f     NaN                NaN
# 6976                    10.0                f     NaN                NaN
# 1436513                 10.0                f     NaN                NaN
# 7651065                 10.0                f     NaN                NaN
# ...                      ...              ...     ...                ...
# 8373729                  9.0                f     NaN                NaN
# 14844274                 NaN                f     NaN                NaN
# 14585486                 NaN                f     NaN                NaN
# 14603878                 7.0                f     NaN                NaN
# 14504422                 NaN                f     NaN                NaN
#
#          instant_bookable cancellation_policy require_guest_profile_picture  \
# id
# 12147973                f            moderate                             f
# 3075044                 t            moderate                             f
# 6976                    f            moderate                             t
# 1436513                 f            moderate                             f
# 7651065                 f            flexible                             f
# ...                   ...                 ...                           ...
# 8373729                 t              strict                             f
# 14844274                f              strict                             f
# 14585486                f            flexible                             f
# 14603878                f              strict                             f
# 14504422                t            flexible                             f
#
#          require_guest_phone_verification  calculated_host_listings_count  \
# id
# 12147973                                f                               1
# 3075044                                 f                               1
# 6976                                    f                               1
# 1436513                                 f                               1
# 7651065                                 f                               1
# ...                                   ...                             ...
# 8373729                                 f                               8
# 14844274                                f                               2
# 14585486                                f                               1
# 14603878                                f                               1
# 14504422                                f                               3
#
#          reviews_per_month
# id
# 12147973               NaN
# 3075044               1.30
# 6976                  0.47
# 1436513               1.00
# 7651065               2.25
# ...                    ...
# 8373729               0.34
# 14844274               NaN
# 14585486               NaN
# 14603878              2.00
# 14504422               NaN
#
# [3585 rows x 94 columns]

# %% [markdown]
# ### Data cleaning and transformations¶

# %%
#clean dataset 
def clean_listing_dataset ():
    """
Remove columns from the data set that are not useful for price prediction .
Remove columns that has very high percentage of na values .
Transform price and other numeric columns from string to int,float type.
    """
    _cols_to_drop = ['listing_url', 'thumbnail_url', 'medium_url', 'picture_url', 'picture_url', 
             'xl_picture_url', 'host_url', 'host_thumbnail_url', 'host_picture_url', 
             'city','state','country','country_code','market','requires_license',
            'experiences_offered','first_review', 'last_review','calendar_last_scraped',
       'calendar_updated', 'scrape_id', 'last_scraped', 'space', 'host_neighbourhood', 
        'neighborhood_overview', 'host_listings_count', 'zipcode', 'is_location_exact', 'host_location',
       'host_total_listings_count', 'neighbourhood','smart_location','host_id']
    ''' droping columns that are not useful '''
    _listings.drop(_cols_to_drop, axis=1, inplace=True)
    ''' droping columns having no values or less than thres '''
    _thresh = len(_listings) * .35
    _listings.dropna(axis=1, thresh=_thresh, inplace = True)
    
    
    ''' 
    remove $ and comma from price cols, convert it to float and fill na values by mean/median .
    remove $ and comma from price, ignore na values so that we wont get any errors .
    convert cols to float type
    fill na values with median
    '''
    
    for _price_fe in ["cleaning_fee", "security_deposit", "price", "extra_people"]:
        
        _listings[_price_fe] = _listings[_price_fe].map(lambda p : p.replace('$','').replace(',',''), na_action='ignore')
        _listings[_price_fe] = _listings[_price_fe].astype(float)
        _listings[_price_fe].fillna(_listings[_price_fe].median(), inplace=True)

# %%
 '''
 remove % from rate cols and convert it to int .
 replace % with blank .
 fill na values with median .
 convert to int type .
 '''
    
for _rate in ['host_response_rate', 'host_acceptance_rate']:
    _listings[_rate] = _listings[_rate].map(lambda r: r.replace('%',''), na_action='ignore')
    _listings[_rate].fillna(_listings[_rate].median(), inplace=True)
    _listings[_rate] = _listings[_rate].astype(int)
    
    '''
    drop rows having na of ["bathrooms", "bedrooms", "beds"] since they are less in number we can not put any assumption and add bias'
    convert ["bathrooms", "bedrooms", "beds"] into int as they make more sense . 
    '''
    
_listings.dropna(axis=0, subset=["bathrooms", "bedrooms", "beds"], inplace=True)
    
for _room in ["bathrooms", "bedrooms", "beds"]:
        _listings[_room] = _listings[_room].astype(int)
for _review in ["review_scores_rating", "review_scores_accuracy", "review_scores_cleanliness", 
                    "review_scores_checkin", "review_scores_communication", "review_scores_location", 
                    "review_scores_value", "reviews_per_month"]:

    _listings[_review].fillna(_listings[_review].median(), inplace=True)
print('data set after cleaning ::')
print(_listings.info())
    
clean_listing_dataset()
# Out:
# data set after cleaning ::
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3557 entries, 12147973 to 14504422
# Data columns (total 94 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   listing_url                       3557 non-null   object
#  1   scrape_id                         3557 non-null   float64
#  2   last_scraped                      3557 non-null   object
#  3   name                              3557 non-null   object
#  4   summary                           3431 non-null   object
#  5   space                             2503 non-null   object
#  6   description                       3557 non-null   object
#  7   experiences_offered               3557 non-null   object
#  8   neighborhood_overview             2162 non-null   object
#  9   notes                             1604 non-null   object
#  10  transit                           2287 non-null   object
#  11  access                            2089 non-null   object
#  12  interaction                       2024 non-null   object
#  13  house_rules                       2377 non-null   object
#  14  thumbnail_url                     2965 non-null   object
#  15  medium_url                        2965 non-null   object
#  16  picture_url                       3557 non-null   object
#  17  xl_picture_url                    2965 non-null   object
#  18  host_id                           3557 non-null   int64
#  19  host_url                          3557 non-null   object
#  20  host_name                         3557 non-null   object
#  21  host_since                        3557 non-null   object
#  22  host_location                     3546 non-null   object
#  23  host_about                        2255 non-null   object
#  24  host_response_time                3088 non-null   object
#  25  host_response_rate                3557 non-null   int32
#  26  host_acceptance_rate              3557 non-null   int32
#  27  host_is_superhost                 3557 non-null   object
#  28  host_thumbnail_url                3557 non-null   object
#  29  host_picture_url                  3557 non-null   object
#  30  host_neighbourhood                3223 non-null   object
#  31  host_listings_count               3557 non-null   int64
#  32  host_total_listings_count         3557 non-null   int64
#  33  host_verifications                3557 non-null   object
#  34  host_has_profile_pic              3557 non-null   object
#  35  host_identity_verified            3557 non-null   object
#  36  street                            3557 non-null   object
#  37  neighbourhood                     3020 non-null   object
#  38  neighbourhood_cleansed            3557 non-null   object
#  39  neighbourhood_group_cleansed      0 non-null      float64
#  40  city                              3555 non-null   object
#  41  state                             3557 non-null   object
#  42  zipcode                           3521 non-null   object
#  43  market                            3543 non-null   object
#  44  smart_location                    3557 non-null   object
#  45  country_code                      3557 non-null   object
#  46  country                           3557 non-null   object
#  47  latitude                          3557 non-null   float64
#  48  longitude                         3557 non-null   float64
#  49  is_location_exact                 3557 non-null   object
#  50  property_type                     3554 non-null   object
#  51  room_type                         3557 non-null   object
#  52  accommodates                      3557 non-null   int64
#  53  bathrooms                         3557 non-null   int32
#  54  bedrooms                          3557 non-null   int32
#  55  beds                              3557 non-null   int32
#  56  bed_type                          3557 non-null   object
#  57  amenities                         3557 non-null   object
#  58  square_feet                       56 non-null     float64
#  59  price                             3557 non-null   object
#  60  weekly_price                      888 non-null    object
#  61  monthly_price                     874 non-null    object
#  62  security_deposit                  1337 non-null   object
#  63  cleaning_fee                      2464 non-null   object
#  64  guests_included                   3557 non-null   int64
#  65  extra_people                      3557 non-null   object
#  66  minimum_nights                    3557 non-null   int64
#  67  maximum_nights                    3557 non-null   int64
#  68  calendar_updated                  3557 non-null   object
#  69  has_availability                  0 non-null      float64
#  70  availability_30                   3557 non-null   int64
#  71  availability_60                   3557 non-null   int64
#  72  availability_90                   3557 non-null   int64
#  73  availability_365                  3557 non-null   int64
#  74  calendar_last_scraped             3557 non-null   object
#  75  number_of_reviews                 3557 non-null   int64
#  76  first_review                      2807 non-null   object
#  77  last_review                       2807 non-null   object
#  78  review_scores_rating              3557 non-null   float64
#  79  review_scores_accuracy            3557 non-null   float64
#  80  review_scores_cleanliness         3557 non-null   float64
#  81  review_scores_checkin             3557 non-null   float64
#  82  review_scores_communication       3557 non-null   float64
#  83  review_scores_location            3557 non-null   float64
#  84  review_scores_value               3557 non-null   float64
#  85  requires_license                  3557 non-null   object
#  86  license                           0 non-null      float64
#  87  jurisdiction_names                0 non-null      float64
#  88  instant_bookable                  3557 non-null   object
#  89  cancellation_policy               3557 non-null   object
#  90  require_guest_profile_picture     3557 non-null   object
#  91  require_guest_phone_verification  3557 non-null   object
#  92  calculated_host_listings_count    3557 non-null   int64
#  93  reviews_per_month                 3557 non-null   float64
# dtypes: float64(16), int32(5), int64(13), object(60)
# memory usage: 2.5+ MB
# None

# %% [markdown]
# drop columns that are not useful, drop columns having fewer values, fill na values and converting some object type columns to numeric columns.

# %% [markdown]
# ### Numerical features analysis

# %%
# visualize numerical of dataset
plt.figure(figsize=(10,8))
plt.title('Price distribution')
sns.histplot(_listings['price'], kde=True, fill=True)
plt.show()

print(_listings['price'].describe())
# Out:
# count    3557.000000
# mean      174.136351
# std       148.710580
# min        10.000000
# 25%        85.000000
# 50%       150.000000
# 75%       220.000000
# max      4000.000000
# Name: price, dtype: float64

# %% [markdown]
#  price is distributed

# %% [markdown]
# ### remove outliers

# %%
#check outliers and remove
_listings_new = _listings[(_listings['price'] > 20) & (_listings['price'] < 500)]

fig, axs = plt.subplots(1, 2, figsize=(24, 8), dpi=80)
axs[0].set_title('Price distribution')
axs[1].set_title('Log base 2 Price distribution')
sns.histplot(_listings_new['price'], kde=True, ax=axs[0])
sns.histplot(_listings_new['price'].astype(int), kde=True, log_scale=2, ax=axs[1])
plt.show()

print(_listings['price'].describe())
# Out:
# count    3557.000000
# mean      174.136351
# std       148.710580
# min        10.000000
# 25%        85.000000
# 50%       150.000000
# 75%       220.000000
# max      4000.000000
# Name: price, dtype: float64

# %% [markdown]
# ### Correlation Matrix of all Numerical columns

# %%
#corrlation and visualize dataset
_corr = _listings_new.select_dtypes(include=['int64', 'float64']).corr()
_mask = np.zeros_like(_corr)
_mask[np.triu_indices_from(_mask)] = True
plt.figure(figsize=(24,12))
plt.title('Heatmap of corr of features')
sns.heatmap(_corr, mask = _mask, vmax=.3, square=True, annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %% [markdown]
# We can see that cleaning_fee, guests_included, security_deposit, beds, bedrooms, bathrooms, accommodates, longitude, latitude, etc are having a strong relationship with price. We must select these columns for our model.
# Surprisingly the number of reviews and reviews per month has a negative relationship with price. We can omit such features.

# %% [markdown]
# ### Categorical Features Analysis

# %%
#check type of dataset
_listings_new.select_dtypes(include=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3463 entries, 12147973 to 14504422
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   name                              3463 non-null   object
#  1   summary                           3339 non-null   object
#  2   description                       3463 non-null   object
#  3   notes                             1566 non-null   object
#  4   transit                           2229 non-null   object
#  5   access                            2033 non-null   object
#  6   interaction                       1973 non-null   object
#  7   house_rules                       2315 non-null   object
#  8   host_name                         3463 non-null   object
#  9   host_since                        3463 non-null   object
#  10  host_about                        2199 non-null   object
#  11  host_response_time                3016 non-null   object
#  12  host_is_superhost                 3463 non-null   object
#  13  host_verifications                3463 non-null   object
#  14  host_has_profile_pic              3463 non-null   object
#  15  host_identity_verified            3463 non-null   object
#  16  street                            3463 non-null   object
#  17  neighbourhood_cleansed            3463 non-null   object
#  18  property_type                     3460 non-null   object
#  19  room_type                         3463 non-null   object
#  20  bed_type                          3463 non-null   object
#  21  amenities                         3463 non-null   object
#  22  instant_bookable                  3463 non-null   object
#  23  cancellation_policy               3463 non-null   object
#  24  require_guest_profile_picture     3463 non-null   object
#  25  require_guest_phone_verification  3463 non-null   object
# dtypes: object(26)
# memory usage: 730.5+ KB

# %%
# print info of new value after clean 
_listings_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3463 entries, 12147973 to 14504422
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   name                              3463 non-null   object
#  1   summary                           3339 non-null   object
#  2   description                       3463 non-null   object
#  3   notes                             1566 non-null   object
#  4   transit                           2229 non-null   object
#  5   access                            2033 non-null   object
#  6   interaction                       1973 non-null   object
#  7   house_rules                       2315 non-null   object
#  8   host_name                         3463 non-null   object
#  9   host_since                        3463 non-null   object
#  10  host_about                        2199 non-null   object
#  11  host_response_time                3016 non-null   object
#  12  host_response_rate                3463 non-null   int32
#  13  host_acceptance_rate              3463 non-null   int32
#  14  host_is_superhost                 3463 non-null   object
#  15  host_verifications                3463 non-null   object
#  16  host_has_profile_pic              3463 non-null   object
#  17  host_identity_verified            3463 non-null   object
#  18  street                            3463 non-null   object
#  19  neighbourhood_cleansed            3463 non-null   object
#  20  latitude                          3463 non-null   float64
#  21  longitude                         3463 non-null   float64
#  22  property_type                     3460 non-null   object
#  23  room_type                         3463 non-null   object
#  24  accommodates                      3463 non-null   int64
#  25  bathrooms                         3463 non-null   int32
#  26  bedrooms                          3463 non-null   int32
#  27  beds                              3463 non-null   int32
#  28  bed_type                          3463 non-null   object
#  29  amenities                         3463 non-null   object
#  30  price                             3463 non-null   float64
#  31  security_deposit                  3463 non-null   float64
#  32  cleaning_fee                      3463 non-null   float64
#  33  guests_included                   3463 non-null   int64
#  34  extra_people                      3463 non-null   float64
#  35  minimum_nights                    3463 non-null   int64
#  36  maximum_nights                    3463 non-null   int64
#  37  availability_30                   3463 non-null   int64
#  38  availability_60                   3463 non-null   int64
#  39  availability_90                   3463 non-null   int64
#  40  availability_365                  3463 non-null   int64
#  41  number_of_reviews                 3463 non-null   int64
#  42  review_scores_rating              3463 non-null   float64
#  43  review_scores_accuracy            3463 non-null   float64
#  44  review_scores_cleanliness         3463 non-null   float64
#  45  review_scores_checkin             3463 non-null   float64
#  46  review_scores_communication       3463 non-null   float64
#  47  review_scores_location            3463 non-null   float64
#  48  review_scores_value               3463 non-null   float64
#  49  instant_bookable                  3463 non-null   object
#  50  cancellation_policy               3463 non-null   object
#  51  require_guest_profile_picture     3463 non-null   object
#  52  require_guest_phone_verification  3463 non-null   object
#  53  calculated_host_listings_count    3463 non-null   int64
#  54  reviews_per_month                 3463 non-null   float64
# dtypes: float64(14), int32(5), int64(10), object(26)
# memory usage: 1.4+ MB

# %% [markdown]
# #  Data Modeling

# %% [markdown]
# ### Data preparation for model

# %%
# select numeric cols
_num_cols = ['price', 'latitude','longitude', 'accommodates', 'bedrooms', 'bathrooms', 'beds', 'security_deposit', 
             'cleaning_fee', 'guests_included', 'availability_30', 'availability_60', 'availability_90', 
             'availability_365', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 
             'review_scores_location', 'review_scores_value', 'calculated_host_listings_count']

_numeric = _listings_new.select_dtypes(include=['int32','int64' ,'float64'])[_num_cols]
print(_numeric.info())

# transform categorical columns into numeric and prepare new data frame
_cat_cols = ['host_response_time', 'host_is_superhost', 'room_type', 'bed_type', 'neighbourhood_cleansed',
             'cancellation_policy', 'property_type', 'host_identity_verified', 'instant_bookable',
            'host_has_profile_pic', 'require_guest_profile_picture', 'require_guest_phone_verification']

_numeric[_cat_cols] = _listings_new[_cat_cols]

_num_copy = _numeric.copy()

_num_copy = _num_copy.replace({ "host_is_superhost": {"t": 1, "f": 2}, "instant_bookable": {"t": 1, "f": 2}, 
                                "host_identity_verified": {"t": 1, "f": 2}, "require_guest_profile_picture": {"t": 1, "f": 2},
                                "room_type": {"Entire home/apt": 1, "Private room": 2, "Shared room": 3}, "host_has_profile_pic": {"t": 1, "f": 2},
                               "bed_type": {"Real Bed": 1, "Futon": 2, "Airbed": 3, "Pull-out Sofa": 4, "Couch": 5},
                               "require_guest_phone_verification": {"t": 1, "f": 2},
                               "cancellation_policy": {"moderate": 1, "flexible": 2, "strict": 3, "super_strict_30": 4}})

_dummies = pd.get_dummies(_num_copy)
print(_dummies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3463 entries, 12147973 to 14504422
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   price                           3463 non-null   float64
#  1   latitude                        3463 non-null   float64
#  2   longitude                       3463 non-null   float64
#  3   accommodates                    3463 non-null   int64
#  4   bedrooms                        3463 non-null   int32
#  5   bathrooms                       3463 non-null   int32
#  6   beds                            3463 non-null   int32
#  7   security_deposit                3463 non-null   float64
#  8   cleaning_fee                    3463 non-null   float64
#  9   guests_included                 3463 non-null   int64
#  10  availability_30                 3463 non-null   int64
#  11  availability_60                 3463 non-null   int64
#  12  availability_90                 3463 non-null   int64
#  13  availability_365                3463 non-null   int64
#  14  review_scores_rating            3463 non-null   float64
#  15  review_scores_accuracy          3463 non-null   float64
#  16  review_scores_cleanliness       3463 non-null   float64
#  17  review_scores_location          3463 non-null   float64
#  18  review_scores_value             3463 non-null   float64
#  19  calculated_host_listings_count  3463 non-null   int64
# dtypes: float64(10), int32(3), int64(7)
# memory usage: 527.6 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3463 entries, 12147973 to 14504422
# Data columns (total 71 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   price                                           3463 non-null   float64
#  1   latitude                                        3463 non-null   float64
#  2   longitude                                       3463 non-null   float64
#  3   accommodates                                    3463 non-null   int64
#  4   bedrooms                                        3463 non-null   int32
#  5   bathrooms                                       3463 non-null   int32
#  6   beds                                            3463 non-null   int32
#  7   security_deposit                                3463 non-null   float64
#  8   cleaning_fee                                    3463 non-null   float64
#  9   guests_included                                 3463 non-null   int64
#  10  availability_30                                 3463 non-null   int64
#  11  availability_60                                 3463 non-null   int64
#  12  availability_90                                 3463 non-null   int64
#  13  availability_365                                3463 non-null   int64
#  14  review_scores_rating                            3463 non-null   float64
#  15  review_scores_accuracy                          3463 non-null   float64
#  16  review_scores_cleanliness                       3463 non-null   float64
#  17  review_scores_location                          3463 non-null   float64
#  18  review_scores_value                             3463 non-null   float64
#  19  calculated_host_listings_count                  3463 non-null   int64
#  20  host_is_superhost                               3463 non-null   int64
#  21  room_type                                       3463 non-null   int64
#  22  bed_type                                        3463 non-null   int64
#  23  cancellation_policy                             3463 non-null   int64
#  24  host_identity_verified                          3463 non-null   int64
#  25  instant_bookable                                3463 non-null   int64
#  26  host_has_profile_pic                            3463 non-null   int64
#  27  require_guest_profile_picture                   3463 non-null   int64
#  28  require_guest_phone_verification                3463 non-null   int64
#  29  host_response_time_a few days or more           3463 non-null   uint8
#  30  host_response_time_within a day                 3463 non-null   uint8
#  31  host_response_time_within a few hours           3463 non-null   uint8
#  32  host_response_time_within an hour               3463 non-null   uint8
#  33  neighbourhood_cleansed_Allston                  3463 non-null   uint8
#  34  neighbourhood_cleansed_Back Bay                 3463 non-null   uint8
#  35  neighbourhood_cleansed_Bay Village              3463 non-null   uint8
#  36  neighbourhood_cleansed_Beacon Hill              3463 non-null   uint8
#  37  neighbourhood_cleansed_Brighton                 3463 non-null   uint8
#  38  neighbourhood_cleansed_Charlestown              3463 non-null   uint8
#  39  neighbourhood_cleansed_Chinatown                3463 non-null   uint8
#  40  neighbourhood_cleansed_Dorchester               3463 non-null   uint8
#  41  neighbourhood_cleansed_Downtown                 3463 non-null   uint8
#  42  neighbourhood_cleansed_East Boston              3463 non-null   uint8
#  43  neighbourhood_cleansed_Fenway                   3463 non-null   uint8
#  44  neighbourhood_cleansed_Hyde Park                3463 non-null   uint8
#  45  neighbourhood_cleansed_Jamaica Plain            3463 non-null   uint8
#  46  neighbourhood_cleansed_Leather District         3463 non-null   uint8
#  47  neighbourhood_cleansed_Longwood Medical Area    3463 non-null   uint8
#  48  neighbourhood_cleansed_Mattapan                 3463 non-null   uint8
#  49  neighbourhood_cleansed_Mission Hill             3463 non-null   uint8
#  50  neighbourhood_cleansed_North End                3463 non-null   uint8
#  51  neighbourhood_cleansed_Roslindale               3463 non-null   uint8
#  52  neighbourhood_cleansed_Roxbury                  3463 non-null   uint8
#  53  neighbourhood_cleansed_South Boston             3463 non-null   uint8
#  54  neighbourhood_cleansed_South Boston Waterfront  3463 non-null   uint8
#  55  neighbourhood_cleansed_South End                3463 non-null   uint8
#  56  neighbourhood_cleansed_West End                 3463 non-null   uint8
#  57  neighbourhood_cleansed_West Roxbury             3463 non-null   uint8
#  58  property_type_Apartment                         3463 non-null   uint8
#  59  property_type_Bed & Breakfast                   3463 non-null   uint8
#  60  property_type_Boat                              3463 non-null   uint8
#  61  property_type_Camper/RV                         3463 non-null   uint8
#  62  property_type_Condominium                       3463 non-null   uint8
#  63  property_type_Dorm                              3463 non-null   uint8
#  64  property_type_Entire Floor                      3463 non-null   uint8
#  65  property_type_Guesthouse                        3463 non-null   uint8
#  66  property_type_House                             3463 non-null   uint8
#  67  property_type_Loft                              3463 non-null   uint8
#  68  property_type_Other                             3463 non-null   uint8
#  69  property_type_Townhouse                         3463 non-null   uint8
#  70  property_type_Villa                             3463 non-null   uint8
# dtypes: float64(10), int32(3), int64(16), uint8(42)
# memory usage: 913.1 KB
# None

# %% [markdown]
# Prepare final dataset containing selected numerical and categorical features. I will first select numerical columns. Next,  transform the categorical columns into numerical/binary vectors.by data frame and converts categorical columns into binary vector representations which are cool.
#
# to extract input (X) and output (y) features to train and evaluate a model.

# %% [markdown]
# # Data Modeling

# %%
# model to predict pricing
y = np.log2(_dummies['price'].astype(int))
X = _dummies.drop('price',  axis =1 )

# split test and train dataset from X and y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=45)

def evaluate_model(_model, x_train, y_train, x_test, y_test):
    _model.fit(x_train, y_train)
    _prediction = _model.predict(x_test)
    _mean_abs_err = mean_absolute_error(y_test, _prediction)
    
    fig, axs = plt.subplots(1, 2, figsize=(24, 8), dpi=80)
    axs[0].set_title('Distribution of predicted vs actual values')
    ax1 = sns.kdeplot(data=y_test, color="g", label='Actual values', ax=axs[0])
    ax2 = sns.kdeplot(data=_prediction, color="b", label='Predicted values', ax=ax1)
    
    sns.regplot(x=y_test, y=_prediction)
    plt.title('Distribution of predicted vs actual values')
    plt.xlabel('Price')
    plt.legend()
    plt.show()
    plt.close()
    
    print("Mean absolute error of {0}: {1}".format(_model, _mean_abs_err))

# Create instance of Random Forest Regressor and evaluate model
_model_rf = RandomForestRegressor(n_estimators=76, random_state=47)    
evaluate_model(_model_rf, X_train, y_train, X_test, y_test)

# Create instance of Linear Regressor and evaluate the same
_model_lr = LinearRegression()
evaluate_model(_model_lr, X_train, y_train, X_test, y_test)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Mean absolute error of RandomForestRegressor(n_estimators=76, random_state=47): 0.3209055605050575
# Mean absolute error of LinearRegression(): 0.3664547626561915

# %% [markdown]
# # Evaluate the Result

# %% [markdown]
#  ### What Features are affecting the price most? name the features that affect the price most.

# %% [markdown]
# Answer: Based on the study we can see that the following features are affecting the price:
#
# Selected Numerical Features:
#
# price, latitude,longitude, accommodates, bedrooms, bathrooms, beds, security_deposit, cleaning_fee, guests_included, availability_30, availability_60, availability_90, availability_365, review_score_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_location, review-scores_value, calculated_host_listings_count.
#
# Selected Categorical Features:
#
# host_response_time, host_is_superhost, room_type, bed_type, neighbourhood_cleansed, cancellation_policy, property_type, host_identity_verified, instant_bookable, host_has_profile_pic, require_guest_profile_picture, require_guest_phone_verification.

# %% [markdown]
# ### Can we predict the price of a listing in Boston AirBnB?

# %% [markdown]
# Answer: RandomForestRegressor did a better job as compare to LinearRegressor. The absolute mean error for RFR is 0.31 whereas 0.35 for LR.

# %% [markdown]
# ### What is the highest proportion in each cancellation_policy category ?

# %%
status_vals = _listings.cancellation_policy.value_counts()
status_vals
# Out:
# strict             1576
# flexible            992
# moderate            914
# super_strict_30      75
# Name: cancellation_policy, dtype: int64

# %%
status_vals = _listings.cancellation_policy.value_counts()#Provide a pandas series of the counts for each Professional status

# The below should be a bar chart of the proportion of individuals in each professional category if your status_vals
# is set up correctly.

(status_vals/_listings.shape[0]).plot(kind="bar");
plt.title("cancellation_policy");

# %% [markdown]
# Answer: Based on the graph we can see the highest proportion in each cancellation_policy is:strict

# %% [markdown]
# ### What is the highest proportion in each review_scores_rating category ?

# %%
review_vals = _listings.review_scores_rating.value_counts()
review_vals
# Out:
# 95.0     977
# 100.0    626
# 93.0     204
# 96.0     197
# 97.0     168
# 90.0     162
# 80.0     160
# 98.0     153
# 94.0     108
# 92.0     103
# 91.0      85
# 87.0      84
# 88.0      67
# 99.0      65
# 89.0      55
# 86.0      46
# 85.0      39
# 84.0      34
# 60.0      33
# 83.0      30
# 70.0      19
# 75.0      16
# 82.0      15
# 73.0      14
# 78.0      11
# 40.0      11
# 79.0      10
# 77.0       9
# 76.0       7
# 81.0       7
# 20.0       6
# 64.0       5
# 74.0       5
# 71.0       4
# 67.0       4
# 65.0       3
# 50.0       3
# 68.0       2
# 47.0       2
# 66.0       2
# 72.0       1
# 53.0       1
# 69.0       1
# 55.0       1
# 48.0       1
# 46.0       1
# Name: review_scores_rating, dtype: int64

# %%
review_vals = _listings.review_scores_rating.value_counts()#Provide a pandas series of the counts for each Professional status

# The below should be a bar chart of the proportion of individuals in each professional category if your status_vals
# is set up correctly.

(review_vals/_listings.shape[0]).plot(kind="bar");
plt.title("review_scores_rating");

# %% [markdown]
# Answer:Based on the graph we can see the highest proportion in each review_scores_rating is:91.95
